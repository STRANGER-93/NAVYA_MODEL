# %% [markdown]
# # NAVYA — Boosting Learning-Curve Diagnostic
#
# This notebook diagnoses how validation loss changes across the boosting rounds in the XGBRegressor configuration already selected by Notebook 05. In XGBoost, each added tree is one boosting round; this is not an epoch-based neural-network training loop. The experiment predicts **only** `next_cycle_length_days`.

# %% [markdown]
# ## 1. Imports, feature contract, and woman-wise partitions
#
# This cell loads the model-ready dataset and exactly recreates the deterministic 800/100/100 woman split. Test women are retained untouched; Notebook 05 has already selected the XGBoost configuration using grouped CV.

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

RANDOM_STATE = 42
ROOT = Path.cwd().resolve()
if not (ROOT / "data").exists():
    ROOT = ROOT.parent
FEATURES = [
    "age_years",
    "menarche_age",
    "height_cm",
    "weight_kg",
    "bmi",
    "sleep_hours",
    "stress_level",
    "exercise_frequency",
    "uses_medication_or_contraceptive",
    "prev_cycle_1",
    "prev_cycle_2",
    "prev_cycle_3",
    "avg_previous_cycle_length",
    "std_previous_cycle_length",
    "prev_period_1",
    "prev_period_2",
    "prev_period_3",
    "avg_previous_period_length",
]
df = pd.read_csv(ROOT / "processed_data" / "model_ready_dataset.csv")
women = np.random.RandomState(RANDOM_STATE).permutation(
    np.sort(df["woman_id"].unique())
)
assert len(women) == 1000
train = df[df.woman_id.isin(women[:800])].copy()
validation = df[df.woman_id.isin(women[800:900])].copy()
assert not (set(train.woman_id) & set(validation.woman_id))
print(f"Rows — train: {len(train):,}; validation: {len(validation):,}")
print("The final test women are deliberately not used in this diagnostic notebook.")
# Out:
# Rows — train: 16,000; validation: 2,000
# The final test women are deliberately not used in this diagnostic notebook.

# %% [markdown]
# ## 2. Fit the selected XGBoost model
#
# We fit the exact number of trees selected by Notebook 05. The median imputer is learned from training women only. XGBoost records validation RMSE after every boosting round, which is squared to obtain validation MSE.

# %%
import json
with open(ROOT / "results" / "tuning" / "best_tuned_model.json") as f: selected = json.load(f)
assert selected["model"] == "XGBRegressor", "Run Notebook 05 first: this diagnostic follows the selected XGBRegressor configuration."
params = {key.replace("model__", ""): value for key, value in selected["best_params"].items()}
MAX_ITERATIONS = int(params.pop("n_estimators"))
X_train, y_train = train[FEATURES], train["next_cycle_length_days"]
X_val, y_val = validation[FEATURES], validation["next_cycle_length_days"]
imputer = SimpleImputer(strategy="median")
X_train_imputed = imputer.fit_transform(X_train)
X_val_imputed = imputer.transform(X_val)
estimator = XGBRegressor(
    n_estimators=MAX_ITERATIONS, random_state=RANDOM_STATE, n_jobs=-1,
    objective="reg:squarederror", eval_metric="rmse", **params,
)
estimator.fit(X_train_imputed, y_train, eval_set=[(X_val_imputed, y_val)], verbose=False)
model = Pipeline([("imputer", imputer), ("model", estimator)])
print(f"Fitted the authoritative XGBRegressor configuration for {MAX_ITERATIONS} boosting rounds on training women only.")
# Out:
# Fitted the authoritative XGBRegressor configuration for 250 boosting rounds on training women only.

# %% [markdown]
# ## 3. Calculate validation loss at every boosting iteration
#
# Validation MSE is recorded after tree 1 through the selected number of XGBoost boosting rounds. The lowest point is descriptive only: it does not replace Notebook 05's grouped-CV selection decision.

# %%
validation_rmse = np.asarray(estimator.evals_result()["validation_0"]["rmse"], dtype=float)
validation_mse = validation_rmse ** 2
lowest_observed_iteration = int(np.argmin(validation_mse) + 1)
lowest_observed_validation_mse = float(validation_mse[lowest_observed_iteration - 1])
loss_curve = pd.DataFrame(
    {
        "boosting_iteration": np.arange(1, MAX_ITERATIONS + 1),
        "validation_mse": validation_mse,
    }
)
display(loss_curve.head())
print(f"Authoritatively selected XGBoost boosting rounds (from Notebook 05): {MAX_ITERATIONS}")
print(f"Lowest diagnostic validation MSE occurs at iteration {lowest_observed_iteration}: {lowest_observed_validation_mse:.6f}")
# Out:
#    boosting_iteration  validation_mse
# 0                   1       15.783506
# 1                   2       15.106951
# 2                   3       14.467619
# 3                   4       13.871222
# 4                   5       13.306261
# Authoritatively selected XGBoost boosting rounds (from Notebook 05): 250
# Lowest diagnostic validation MSE occurs at iteration 250: 2.682191

# %% [markdown]
# ## 4. Visualise the selected model's learning curve
#
# The blue curve is the real validation MSE after each XGBoost tree. The red dashed line marks the number of boosting rounds selected by grouped cross-validation in Notebook 05. It is not an independent optimum selected from this chart. `plt.show()` embeds the plot directly in this notebook when the cell is run.

# %%
sns.set_theme(style="whitegrid")
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(
    loss_curve["boosting_iteration"],
    loss_curve["validation_mse"],
    color="#1f77b4",
    linewidth=2,
    label="Validation MSE",
)
ax.axvline(
    MAX_ITERATIONS,
    color="crimson",
    linestyle="--",
    linewidth=2,
    label=f"Selected by grouped CV: {MAX_ITERATIONS}",
)
ax.scatter([MAX_ITERATIONS], [validation_mse[MAX_ITERATIONS - 1]], color="crimson", zorder=3)
ax.set(
    title="Validation MSE across the selected XGBoost model's boosting rounds",
    xlabel="XGBoost boosting round (tree / n_estimators)",
    ylabel="Validation MSE",
)
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Validation-only diagnostic summary
#
# This notebook does not select another configuration and does not access test women. It reports the validation curve for the configuration already selected by Notebook 05; Notebook 09 performs the one final held-out test evaluation.

# %%
metrics = {
    "selected_boosting_iteration": MAX_ITERATIONS,
    "initial_validation_mse": float(validation_mse[0]),
    "selected_iteration_validation_mse": float(validation_mse[MAX_ITERATIONS - 1]),
    "lowest_diagnostic_validation_mse": lowest_observed_validation_mse,
    "lowest_diagnostic_iteration": lowest_observed_iteration,
}
display(pd.DataFrame([metrics]).round(6))
# Out:
#    selected_boosting_iteration  initial_validation_mse  \
# 0                          250               15.783506
#
#    selected_iteration_validation_mse  lowest_diagnostic_validation_mse  \
# 0                           2.682191                          2.682191
#
#    lowest_diagnostic_iteration
# 0                          250

# %% [markdown]
# ## 6. Save reproducible XGBoost learning-curve artifacts
#
# The CSV contains every plotted iteration and the JSON captures the grouped-CV-selected iteration plus validation diagnostics. The final test set is reserved exclusively for Notebook 09.

# %%
import json

metrics_dir = ROOT / "results" / "metrics"
plots_dir = ROOT / "results" / "plots"
metrics_dir.mkdir(parents=True, exist_ok=True)
plots_dir.mkdir(parents=True, exist_ok=True)
loss_curve.to_csv(metrics_dir / "xgb_learning_curve.csv", index=False)
with open(metrics_dir / "xgb_learning_curve_diagnostic.json", "w") as f:
    json.dump(metrics, f, indent=2)
fig.savefig(plots_dir / "xgb_learning_curve.png", dpi=180, bbox_inches="tight")
print("Saved XGBoost learning-curve CSV, metrics JSON, and PNG plot.")
# Out:
# Saved XGBoost learning-curve CSV, metrics JSON, and PNG plot.

# %% [markdown]
# ## 7. Train vs Validation loss curve (overfitting diagnostic)
#
# This cell adds the standard two-line loss curve. XGBoost records loss for **both** the training and validation set when both are passed to eval_set, so the train and validation MSE can be compared across boosting rounds. If the validation curve rises after a minimum while the training curve keeps dropping, the extra trees are overfitting the validation set.

# %%
sns.set_theme(style="whitegrid")
# Refit with BOTH train and validation sets so XGBoost records both loss curves.
# This reuses the variables already defined above (identical config to Notebook 05).
estimator_dual = XGBRegressor(
    n_estimators=MAX_ITERATIONS, random_state=RANDOM_STATE, n_jobs=-1,
    objective="reg:squarederror", eval_metric="rmse", **params,
)
estimator_dual.fit(
    X_train_imputed, y_train,
    eval_set=[(X_train_imputed, y_train), (X_val_imputed, y_val)],
    verbose=False,
)
# XGBoost names the two eval sets validation_0 (train) and validation_1 (val).
train_rmse = np.asarray(estimator_dual.evals_result()["validation_0"]["rmse"], dtype=float)
val_rmse   = np.asarray(estimator_dual.evals_result()["validation_1"]["rmse"], dtype=float)
train_mse  = train_rmse ** 2
val_mse    = val_rmse ** 2
iteration  = np.arange(1, MAX_ITERATIONS + 1)
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(iteration, train_mse, label="Train MSE", color="#2ca02c", linewidth=2)
ax.plot(iteration, val_mse,   label="Validation MSE", color="#1f77b4", linewidth=2)
ax.axvline(MAX_ITERATIONS, color="crimson", linestyle="--", linewidth=2,
           label=f"Selected by grouped CV: {MAX_ITERATIONS} trees")
ax.set(
    title="Train vs validation loss (MSE) across XGBoost boosting rounds",
    xlabel="Boosting round (tree / n_estimators)",
    ylabel="MSE (days squared)",
)
ax.legend()
plt.tight_layout()
plt.savefig(ROOT / "results" / "plots" / "xgb_loss_curve_train_vs_validation.png",
            dpi=180, bbox_inches="tight")
plt.show()
print(f"Last train MSE: {train_mse[-1]:.4f} | Last validation MSE: {val_mse[-1]:.4f}")
# Build and print the FULL 250-round train/val MSE table.
loss_table = pd.DataFrame({
    "boosting_iteration": iteration,
    "train_mse": train_mse,
    "validation_mse": val_mse,
    "gap_val_minus_train": val_mse - train_mse,
})
with pd.option_context("display.max_rows", None, "display.width", 120):
    print("Full train vs validation loss per boosting round (250 rows):")
    print(loss_table.to_string(index=False, float_format=lambda v: f"{v:.6f}"))
# Also save the full table for later reference.
loss_table.to_csv(ROOT / "results" / "metrics" / "xgb_train_vs_validation_loss_curve.csv", index=False)
print("Saved full table to results/metrics/xgb_train_vs_validation_loss_curve.csv")
# Out:
# Last train MSE: 3.1002 | Last validation MSE: 2.6822
# Full train vs validation loss per boosting round (250 rows):
#  boosting_iteration  train_mse  validation_mse  gap_val_minus_train
#                   1  14.277672       15.783506             1.505834
#                   2  13.715475       15.106951             1.391476
#                   3  13.185563       14.467619             1.282056
#                   4  12.688380       13.871222             1.182843
#                   5  12.220976       13.306261             1.085285
#                   6  11.766419       12.754952             0.988533
#                   7  11.344598       12.254607             0.910009
#                   8  10.948333       11.777092             0.828758
#                   9  10.571016       11.324818             0.753802
#                  10  10.204483       10.881351             0.676867
#                  11   9.861601       10.479081             0.617480
#                  12   9.534885       10.088733             0.553848
#                  13   9.228180        9.710377             0.482197
#                  14   8.936779        9.355133             0.418354
#                  15   8.662536        9.031418             0.368882
#                  16   8.405213        8.733233             0.328020
#                  17   8.151591        8.422483             0.270892
#                  18   7.907465        8.128789             0.221324
#                  19   7.679632        7.840247             0.160615
#                  20   7.463037        7.585561             0.122524
#                  21   7.263412        7.349717             0.086305
#                  22   7.065908        7.111757             0.045849
#                  23   6.882389        6.894801             0.012412
#                  24   6.705722        6.682227            -0.023494
#                  25   6.542597        6.506653            -0.035945
#                  26   6.385544        6.329071            -0.056473
#                  27   6.235161        6.150626            -0.084535
#                  28   6.090700        5.977236            -0.113465
#                  29   5.952447        5.811859            -0.140588
#                  30   5.823400        5.660075            -0.163325
#                  31   5.699170        5.514161            -0.185009
#                  32   5.582188        5.380058            -0.202130
#                  33   5.470718        5.272346            -0.198373
#                  34   5.366181        5.151268            -0.214913
#                  35   5.263337        5.018611            -0.244726
#                  36   5.165724        4.902491            -0.263232
#                  37   5.074062        4.797548            -0.276514
#                  38   4.986752        4.698207            -0.288545
#                  39   4.902404        4.600736            -0.301668
#                  40   4.821855        4.505549            -0.316306
#                  41   4.744284        4.428316            -0.315968
#                  42   4.671330        4.350487            -0.320842
#                  43   4.602481        4.272879            -0.329601
#                  44   4.537237        4.193334            -0.343902
#                  45   4.475373        4.120242            -0.355131
#                  46   4.416000        4.050464            -0.365535
#                  47   4.359379        3.987365            -0.372015
#                  48   4.305560        3.923838            -0.381722
#                  49   4.254854        3.867351            -0.387503
#                  50   4.204579        3.821322            -0.383257
#                  51   4.158678        3.769625            -0.389053
#                  52   4.114157        3.723458            -0.390700
#                  53   4.071870        3.676924            -0.394946
#                  54   4.032724        3.628166            -0.404558
#                  55   3.994335        3.583378            -0.410956
#                  56   3.957402        3.541096            -0.416305
#                  57   3.921904        3.507859            -0.414045
#                  58   3.887001        3.470907            -0.416094
#                  59   3.856038        3.439806            -0.416232
#                  60   3.825107        3.408426            -0.416681
#                  61   3.794738        3.374681            -0.420057
#                  62   3.767532        3.341952            -0.425580
#                  63   3.742627        3.312956            -0.429671
#                  64   3.717551        3.282424            -0.435127
#                  65   3.693594        3.256915            -0.436679
#                  66   3.671340        3.232352            -0.438988
#                  67   3.649479        3.206064            -0.443415
#                  68   3.628484        3.181899            -0.446585
#                  69   3.608446        3.163678            -0.444768
#                  70   3.590241        3.145142            -0.445099
#                  71   3.571730        3.128390            -0.443339
#                  72   3.554364        3.108513            -0.445851
#                  73   3.537605        3.091571            -0.446034
#                  74   3.521907        3.072502            -0.449405
#                  75   3.507996        3.056783            -0.451213
#                  76   3.493427        3.040678            -0.452749
#                  77   3.480076        3.026705            -0.453370
#                  78   3.467048        3.012951            -0.454097
#                  79   3.454757        3.002794            -0.451963
#                  80   3.443076        2.987153            -0.455923
#                  81   3.432192        2.975705            -0.456488
#                  82   3.421554        2.962942            -0.458612
#                  83   3.410856        2.952124            -0.458732
#                  84   3.400546        2.942701            -0.457845
#                  85   3.391231        2.931671            -0.459560
#                  86   3.382631        2.921731            -0.460900
#                  87   3.374105        2.914259            -0.459845
#                  88   3.366063        2.906333            -0.459730
#                  89   3.358650        2.897414            -0.461236
#                  90   3.351023        2.886998            -0.464025
#                  91   3.343731        2.879333            -0.464398
#                  92   3.337081        2.871100            -0.465981
#                  93   3.330695        2.865847            -0.464848
#                  94   3.324707        2.858206            -0.466501
#                  95   3.318763        2.851917            -0.466846
#                  96   3.313023        2.844423            -0.468600
#                  97   3.307575        2.837437            -0.470138
#                  98   3.302573        2.830736            -0.471837
#                  99   3.297223        2.826633            -0.470590
#                 100   3.292057        2.821354            -0.470703
#                 101   3.287544        2.817376            -0.470168
#                 102   3.283539        2.814031            -0.469508
#                 103   3.279415        2.808255            -0.471160
#                 104   3.275510        2.804540            -0.470970
#                 105   3.271196        2.798301            -0.472894
#                 106   3.266846        2.792756            -0.474090
#                 107   3.262849        2.789523            -0.473326
#                 108   3.259502        2.787074            -0.472427
#                 109   3.255834        2.782122            -0.473711
#                 110   3.252956        2.779723            -0.473233
#                 111   3.249568        2.777373            -0.472195
#                 112   3.246434        2.773773            -0.472661
#                 113   3.243464        2.772490            -0.470974
#                 114   3.240601        2.768213            -0.472388
#                 115   3.237797        2.765854            -0.471943
#                 116   3.235237        2.762696            -0.472541
#                 117   3.232745        2.759696            -0.473049
#                 118   3.230286        2.756149            -0.474137
#                 119   3.228192        2.755335            -0.472857
#                 120   3.225734        2.751540            -0.474194
#                 121   3.223267        2.750042            -0.473225
#                 122   3.221248        2.748217            -0.473031
#                 123   3.218994        2.746488            -0.472505
#                 124   3.217116        2.743161            -0.473955
#                 125   3.215060        2.740337            -0.474723
#                 126   3.213243        2.740991            -0.472252
#                 127   3.211141        2.738571            -0.472570
#                 128   3.209117        2.738107            -0.471009
#                 129   3.207330        2.737360            -0.469970
#                 130   3.205608        2.736410            -0.469198
#                 131   3.203689        2.734724            -0.468966
#                 132   3.201801        2.734362            -0.467439
#                 133   3.200149        2.734122            -0.466027
#                 134   3.198608        2.731207            -0.467401
#                 135   3.196932        2.730902            -0.466029
#                 136   3.195484        2.728078            -0.467406
#                 137   3.193931        2.728047            -0.465884
#                 138   3.192315        2.726989            -0.465326
#                 139   3.191034        2.725869            -0.465165
#                 140   3.189871        2.725209            -0.464662
#                 141   3.188037        2.724861            -0.463176
#                 142   3.186949        2.723785            -0.463164
#                 143   3.184404        2.721716            -0.462688
#                 144   3.183283        2.720686            -0.462598
#                 145   3.181916        2.719986            -0.461930
#                 146   3.181081        2.719844            -0.461237
#                 147   3.179447        2.718123            -0.461323
#                 148   3.178235        2.717447            -0.460788
#                 149   3.177044        2.715509            -0.461535
#                 150   3.175803        2.715592            -0.460211
#                 151   3.174868        2.714254            -0.460614
#                 152   3.173642        2.712762            -0.460880
#                 153   3.172497        2.712489            -0.460009
#                 154   3.171283        2.712534            -0.458750
#                 155   3.170232        2.712013            -0.458220
#                 156   3.168859        2.711518            -0.457340
#                 157   3.167400        2.711633            -0.455767
#                 158   3.166164        2.710234            -0.455930
#                 159   3.165426        2.708962            -0.456464
#                 160   3.164745        2.708518            -0.456228
#                 161   3.164029        2.708458            -0.455570
#                 162   3.163122        2.708620            -0.454503
#                 163   3.162327        2.708482            -0.453845
#                 164   3.161200        2.708647            -0.452553
#                 165   3.160651        2.707617            -0.453034
#                 166   3.159477        2.706719            -0.452759
#                 167   3.158240        2.705238            -0.453002
#                 168   3.156767        2.703652            -0.453114
#                 169   3.155690        2.703876            -0.451814
#                 170   3.154784        2.703090            -0.451694
#                 171   3.153718        2.700837            -0.452880
#                 172   3.152783        2.701199            -0.451584
#                 173   3.151681        2.699582            -0.452099
#                 174   3.150875        2.699416            -0.451460
#                 175   3.150070        2.698311            -0.451759
#                 176   3.149726        2.697116            -0.452610
#                 177   3.148918        2.697475            -0.451443
#                 178   3.148012        2.696491            -0.451521
#                 179   3.146739        2.697126            -0.449614
#                 180   3.145595        2.697729            -0.447866
#                 181   3.144566        2.698453            -0.446113
#                 182   3.143576        2.697785            -0.445791
#                 183   3.142820        2.698355            -0.444465
#                 184   3.142453        2.699361            -0.443093
#                 185   3.140865        2.699042            -0.441823
#                 186   3.139944        2.697977            -0.441967
#                 187   3.139478        2.696913            -0.442565
#                 188   3.138505        2.697700            -0.440805
#                 189   3.137958        2.696492            -0.441466
#                 190   3.137132        2.694058            -0.443074
#                 191   3.136261        2.695055            -0.441206
#                 192   3.135557        2.695664            -0.439893
#                 193   3.134580        2.695119            -0.439461
#                 194   3.133447        2.693724            -0.439723
#                 195   3.132871        2.694263            -0.438608
#                 196   3.131820        2.693244            -0.438577
#                 197   3.130839        2.692128            -0.438711
#                 198   3.130002        2.691496            -0.438506
#                 199   3.129109        2.692247            -0.436862
#                 200   3.128204        2.690778            -0.437426
#                 201   3.127390        2.691101            -0.436289
#                 202   3.126520        2.690980            -0.435540
#                 203   3.125569        2.692469            -0.433100
#                 204   3.125139        2.692311            -0.432829
#                 205   3.124426        2.691282            -0.433144
#                 206   3.124099        2.690975            -0.433124
#                 207   3.123679        2.690401            -0.433278
#                 208   3.123132        2.689621            -0.433512
#                 209   3.122046        2.690308            -0.431739
#                 210   3.121346        2.690586            -0.430760
#                 211   3.120566        2.689846            -0.430720
#                 212   3.120057        2.689262            -0.430795
#                 213   3.119574        2.688789            -0.430785
#                 214   3.118847        2.688625            -0.430222
#                 215   3.118411        2.687904            -0.430507
#                 216   3.117724        2.687236            -0.430489
#                 217   3.117186        2.686842            -0.430344
#                 218   3.116319        2.686229            -0.430090
#                 219   3.115446        2.686378            -0.429068
#                 220   3.114680        2.687191            -0.427489
#                 221   3.114602        2.686740            -0.427862
#                 222   3.114284        2.687273            -0.427011
#                 223   3.113905        2.686370            -0.427535
#                 224   3.113400        2.685492            -0.427908
#                 225   3.113086        2.684587            -0.428499
#                 226   3.112551        2.684321            -0.428230
#                 227   3.112129        2.684270            -0.427859
#                 228   3.111644        2.684784            -0.426861
#                 229   3.111108        2.684234            -0.426874
#                 230   3.110833        2.683947            -0.426886
#                 231   3.110542        2.684532            -0.426010
#                 232   3.110246        2.684422            -0.425824
#                 233   3.109361        2.683417            -0.425944
#                 234   3.108532        2.684663            -0.423869
#                 235   3.108120        2.684012            -0.424109
#                 236   3.107754        2.683523            -0.424230
#                 237   3.107448        2.684182            -0.423265
#                 238   3.106711        2.685816            -0.420895
#                 239   3.106327        2.685299            -0.421028
#                 240   3.105869        2.685060            -0.420809
#                 241   3.105316        2.685022            -0.420294
#                 242   3.104700        2.684140            -0.420561
#                 243   3.104092        2.684094            -0.419997
#                 244   3.102942        2.683219            -0.419723
#                 245   3.102556        2.683274            -0.419282
#                 246   3.101897        2.683382            -0.418514
#                 247   3.101255        2.683217            -0.418039
#                 248   3.100692        2.683098            -0.417594
#                 249   3.100498        2.682541            -0.417958
#                 250   3.100234        2.682191            -0.418043
# Saved full table to results/metrics/xgb_train_vs_validation_loss_curve.csv

# %% [markdown]
# ## Interpretation
#
# A decreasing validation-MSE curve means added XGBoost trees improve validation performance. If the curve rises after its minimum, later trees may be beginning to overfit this validation set. The red line marks the number of boosting rounds selected by grouped CV in Notebook 05; this chart does not independently choose a new value.
